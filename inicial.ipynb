# %%
'''
Ejecutar en Bash

cd edurisk-api
python -m venv .venv
source .venv/bin/activate        # Windows: .venv\Scripts\activate
pip install flask joblib mlflow scikit-learn xgboost python-dotenv
pip freeze > requirements.txt

mkdir -p app/routes app/schemas model src mlflow_tracking tests
# %touch app/__init__.py \
      app/routes/__init__.py \
      app/routes/health.py \
      app/routes/predict.py \
      app/schemas/predict.py \
      mlflow_tracking/register_model.py \
      tests/test_routes.py \
      run.py \
      .env \
      .gitignore \
      Dockerfile \
      docker-compose.yml

cp ../edurisk/src/utils.py src/

'''
